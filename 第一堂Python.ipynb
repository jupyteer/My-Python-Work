# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt

# %%
np.sin(1/2)
# Out:
# 0.479425538604203

# %%
x=np.linspace(-10,10,100,300)

# %%
y=np.tan(x)+np.sin(x/2)+np.pi

# %%
x=np.linspace(-10,10,100,300)
y=np.tan(x)+np.sin(x/2)+np.pi
plt.xkcd()
plt.xlabel("x")
plt.ylabel("Y")
plt.plot(x,y)
