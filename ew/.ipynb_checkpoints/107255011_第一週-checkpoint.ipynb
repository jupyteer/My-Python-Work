# %% [markdown]
# # 第一題：畫出想要的圖形

# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
x=[5,10,7,10,5]

# %%
plt.plot(x)

# %% [markdown]
# # 第二題 台北市最高最低氣溫 (1981-2010)

# %%
l=[19.1,19.6,22.1,25.7,29.2,32,34.3,33.8,31.1,27.5,24.2,20.7]
h=[13.9,14.2,15.8,19,22.3,24.6,26.3,26.1,24.8,22.3,19.3,15.6]

# %%
plt.plot(l)
plt.plot(h)
plt.xlabel('month')
plt.ylabel('temperature')
# Out:
# Text(0, 0.5, 'temperature')

# %%
## 資料來源:https://www.cwb.gov.tw/V8/C/C/Statistics/monthlymean.html

# %% [markdown]
# # 挑戰題

# %%
x=np.linspace(-10,10,100,300)

# %%
y=np.tan(x**3)+np.sin(x**2/2)+np.pi

# %%
plt.xkcd()
plt.xlabel("x")
plt.ylabel("Y")
plt.plot(x,y)
