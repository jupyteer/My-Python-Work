# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
from IPython.display import display, HTML, Markdown, Image, YouTubeVideo

# %%
music = YouTubeVideo("TpF0wNlopp8")

# %%
display(music)  #好像不能用專輯?
