# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
a = int(input("請輸入起始值 =>"))
b = int(input("請輸入最終值 =>"))
s = 0

for i in range(a, b+1):
    s = s + i
    print("i = " + str(i)+" s="+str(s))
    
print("總和 = " + str(s))
# Out:
# 請輸入起始值 =>10
# 請輸入最終值 =>100
# i = 10 s=10
# i = 11 s=21
# i = 12 s=33
# i = 13 s=46
# i = 14 s=60
# i = 15 s=75
# i = 16 s=91
# i = 17 s=108
# i = 18 s=126
# i = 19 s=145
# i = 20 s=165
# i = 21 s=186
# i = 22 s=208
# i = 23 s=231
# i = 24 s=255
# i = 25 s=280
# i = 26 s=306
# i = 27 s=333
# i = 28 s=361
# i = 29 s=390
# i = 30 s=420
# i = 31 s=451
# i = 32 s=483
# i = 33 s=516
# i = 34 s=550
# i = 35 s=585
# i = 36 s=621
# i = 37 s=658
# i = 38 s=696
# i = 39 s=735
# i = 40 s=775
# i = 41 s=816
# i = 42 s=858
# i = 43 s=901
# i = 44 s=945
# i = 45 s=990
# i = 46 s=1036
# i = 47 s=1083
# i = 48 s=1131
# i = 49 s=1180
# i = 50 s=1230
# i = 51 s=1281
# i = 52 s=1333
# i = 53 s=1386
# i = 54 s=1440
# i = 55 s=1495
# i = 56 s=1551
# i = 57 s=1608
# i = 58 s=1666
# i = 59 s=1725
# i = 60 s=1785
# i = 61 s=1846
# i = 62 s=1908
# i = 63 s=1971
# i = 64 s=2035
# i = 65 s=2100
# i = 66 s=2166
# i = 67 s=2233
# i = 68 s=2301
# i = 69 s=2370
# i = 70 s=2440
# i = 71 s=2511
# i = 72 s=2583
# ...
