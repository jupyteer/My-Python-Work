# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt

# %%
np.sin(1/2)
# Out:
# 0.479425538604203

# %%
x=np.linspace(-15,-10,10,100,1000)

# %%
y=tan(x)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-35-c440e4efe6fe> in <module>
# ----> 1 y=tan(x)
#
# NameError: name 'tan' is not defined

# %%
plt.xkcd()
plt.plot(x,y)
